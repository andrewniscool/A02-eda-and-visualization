# %%
# !git clone https://github.com/andrewniscool/A02-eda-and-visualization.git
# Out:
# Cloning into 'A02-eda-and-visualization'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 13 (delta 1), reused 0 (delta 0), pack-reused 8 (from 1)
# Receiving objects: 100% (13/13), 1.28 MiB | 5.38 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
# # Assignment: Exploratory Data Analysis

# %% [markdown]
# **Q1.** In class, we talked about how to compute the sample mean of a variable $X$,
# $$
# m(X) = \dfrac{1}{N} \sum_{i=1}^N x_i
# $$
# and sample covariance of two variables $X$ and $Y$,
# $$
# \text{cov}(X,Y) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(y_i - m(Y)).
# $$
# Recall, the sample variance of $X$ is
# $$
# s^2 = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2.
# $$
# It can be very helpful to understand some basic properties of these statistics. If you want to write your calculations on a piece of paper, take a photo, and upload that to your GitHub repo, that's probably easiest.
#
# 1. Show that $m(a + bX) = a+b \times m(X)$.
# 2. Show that $\text{cov}(X,a+bY) = b \times \text{cov}(X,Y)$
# 3. Show that $\text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X) $, and in particular that $\text{cov}(X,X) = s^2 $.
# 4. Consider a non-decreasing transformation $g()$. Is is always true that $m(g(X))= g(m(X))$?

# %% [markdown]
# **Q2.** This question looks at financial transfers from foreign entities to American universities. In particular, from which countries and giftors are the gifts coming from, and to which institutions are they going? For this question, `.groupby([vars]).count()` and `.groupby([vars]).sum()` will be especially useful to tally the number of occurrences and sum the values of those occurrences.
#
# 1. Load the `./data/ForeignGifts_edu.csv` dataset.
# 2. For `Foreign Gift Amount`, create a histogram and describe the variable. Describe your findings.
# 3. For `Gift Type`, create a histogram or value counts table. What proportion of the gifts are contracts, real estate, and monetary gifts?
# 4. Create a kernel density plot of the log of `Foreign Gift Amount`, and then a kernel density plot of the log of `Foreign Gift Amount` conditional on gift type. Do you notice any patterns?
# 5. What are the top 15 countries in terms of the number of gifts? What are the top 15 countries in terms of the amount given?
# 6. Which giftors provide the most money, in total?

# %% [markdown]
# ---

# %% [markdown]
# ## *Phase 1: Solution without AI
#
# Complete all questions in the following cells without generative AI. Then commit and push the
# notebook before beginning Phase 2.

# %% [markdown]
# **Declaration:** I completed this version without generative AI.
#
# **Student(s):** Andrew Nguyen
#
# **Date:** 9-9-2026

# %% [markdown]
# ## Question 1
# ---
# 1. Show that $m(a + bX) = a+b \times m(X)$.
# Using the original formula:
# $$m(X) = \dfrac{1}{N} \sum_{i=1}^N x_i$$
# we can simplify
# $$m(a + bX) = \frac{1}{N}\sum_{i=1}^{N}(a + bx_i)$$
#
# $= \frac{1}{N}\left(\sum_{i=1}^{N}a + \sum_{i=1}^{N}bx_i\right)$
#
# $= \frac{1}{N}\left(Na + b\sum_{i=1}^{N}x_i\right)$
#
# $= a + b\left(\frac{1}{N}\sum_{i=1}^{N}x_i\right)$
#
# $= a + b \times m(X)$
#
# ---
# 2. Show that $\text{cov}(X,a+bY) = b \times \text{cov}(X,Y)$.
# Using the original formula:
# $$
# \text{cov}(X,Y) = \frac{1}{N} \sum_{i=1}^N (x_i - m(X))(y_i - m(Y)).
# $$
# We can simplify:
# $$\text{cov}(X,a+bY)=\frac{1}{N}\sum_{i=1}^{N}(x_i-m(X))((a+by_i)-(a+b\,m(Y)))$$
#
# $= \text{cov}(X,a+bY)=\frac{1}{N}\sum_{i=1}^{N}(x_i-m(X))((by_i-b\,m(Y)))$
#
# $= \text{cov}(X,a+bY)=\frac{1}{N}\sum_{i=1}^{N}(x_i-m(X))(b(y_i-m(Y)))$
#
# $= \text{cov}(X,a+bY)=b * \frac{1}{N}\sum_{i=1}^{N}(x_i-m(X))(y_i-m(Y))$
#
# $= \text{cov}(X,a+bY)=b * \text{cov}(X,Y)$
#
# ---
# 3. Show that $\text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X) $, and in particular that $\text{cov}(X,X) = s^2 $. Using the original formulas
# $$
# \text{cov}(X,Y) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(y_i - m(Y)).
# $$
# we can simplify:
# $$\text{cov}(a+bX,a+bX)$$
#
# $= \frac{1}{N}\sum_{i=1}^{N}((a+bx_i)-m(a+bX))((a+bx_i)-m(a+bX))$
#
# $= \frac{1}{N}\sum_{i=1}^{N}((a+bx_i) - (a + m(bX)))((a+bx_i) - (a + m(bX)))$
#
# $= \frac{1}{N}\sum_{i=1}^{N}(bx_i-m(bX))(bx_i-m(bX))$
#
# $= \frac{1}{N}\sum_{i=1}^{N}(bx_i-(b * m(X)))(bx_i-(b * m(X)))$
#
# $= \frac{1}{N}\sum_{i=1}^{N}(bx_i-(b * m(X))) ^ 2$
#
# $= \frac{1}{N}\sum_{i=1}^{N}(b * (x_i-m(X))) ^ 2$
#
# $= \frac{1}{N}\sum_{i=1}^{N}(b ^ 2 * (x_i-m(X))^ 2)$
#
# Since:
#
# $$\text{cov}(X, X) = (x_i-m(X))^ 2$$
#
# Then:
#
# $$b ^ 2 * \frac{1}{N}\sum_{i=1}^{N}(x_i-m(X)) ^ 2$$
# $= b ^ 2 * \text{cov}(X, X)$
#
# So:
#
# $$\text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X)$$
#
# then, using this formula:
# $$
# s^2 = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2.
# $$
# we can simplify the previous formula into:
#
# $$\frac{1}{N}\sum_{i=1}^{N}(b * (x_i-m(X))) ^ 2$$
#
# $$= b ^ 2 * \frac{1}{N}\sum_{i=1}^{N}(x_i-m(X)) ^ 2$$
#
# $$= b ^ 2 * s ^ 2$$
#
# so:
# $\text{cov}(X,X) = s^2 $
#
# ---
# 4. Consider a non-decreasing transformation $g()$. Is is always true that $m(g(X))= g(m(X))$?
#
# In order to prove this we can try finding a counterexample to prove that it is not ***always*** true.
#
# we can try this: g(x) = x^3 (this function is non-decreasing), and the numbers 0 and 2.
#
# m(g(x)):
#
# g(0) = 0, g(2) = 8. m(0, 8) = (8 - 0) / 2 = 4
#
# g(m(x)):
#
# m(0, 2) = (2 - 0) / 2 = 1, g(1) = 1
#
# Since 4 is not equal to 1, this statement is not ***always*** true.

# %% [markdown]
# ### Question 2:
#
# 1. Load the `./data/ForeignGifts_edu.csv` dataset.
# 2. For `Foreign Gift Amount`, create a histogram and describe the variable. Describe your findings.
# ---
# For `Foreign Gift Amount`, the histogram seems to be heavily right skewed. Most gifts are relatively small, and most of them are concentrated near the lower end of the distribution. There are little to no extremely large gifts. The mean is around 588,000 dollars, while the median is only 94,615 dollars. The max is 100 million dollars, meaning there are extreme outliers. There also seems to be some negative amounts, as the minimum seems to be -537,770 dollars.

# %%
# Your Phase 1 solution to the problem goes here.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

foreign_gifts_df = pd.read_csv("A02-eda-and-visualization/data/ForeignGifts_edu.csv")

foreign_gifts_df["Foreign Gift Amount"].hist(bins=20, grid=False)

plt.xlabel("Foreign Gift Amount")
plt.ylabel("Count")

plt.show()

foreign_gifts_df["Foreign Gift Amount"].describe()
# Out:
# count    2.822100e+04
# mean     5.882327e+05
# std      3.222011e+06
# min     -5.377700e+05
# 25%      5.700000e+03
# 50%      9.461500e+04
# 75%      3.761420e+05
# max      1.000000e+08
# Name: Foreign Gift Amount, dtype: float64

# %% [markdown]
# 3. For `Gift Type`, create a histogram or value counts table. What proportion of the gifts are contracts, real estate, and monetary gifts?
# ---
# There's 17274 contracts, 10936 monetary gifts, and 11 real estate gifts. The percentage of gifts that were contracts is around 61.2%, for Monetary Gifts it was 38.8%, and for Real estate it was 0.04%.

# %%
foreign_gifts_df["Gift Type"].value_counts()
# Out:
# Gift Type
# Contract         17274
# Monetary Gift    10936
# Real Estate         11
# Name: count, dtype: int64

# %%
print((17274 / 28221) * 100)
print((10936 / 28221) * 100)
print((11 / 28221) * 100)
# Out:
# 61.20973742957372
# 38.75128450444704
# 0.038978065979235324

# %% [markdown]
# 4. Create a kernel density plot of the log of `Foreign Gift Amount`, and then a kernel density plot of the log of `Foreign Gift Amount` conditional on gift type. Do you notice any patterns?
# ---
# Yes, Contract gifts seem to take up the most density by far, followed by Monetary Gifts, and the Real estate gifts. Real Estate gifts take little to almost none of the density, and this data aligns well with the proportions found in question 2.3.

# %%
foreign_gifts_df["Log Foreign Gift Amount"] = np.log(foreign_gifts_df["Foreign Gift Amount"])

sns.kdeplot(data=foreign_gifts_df, x="Log Foreign Gift Amount")

plt.xlabel("Log Foreign Gift Amount")
plt.title("Density of Log Foreign Gift Amount")
plt.show()
# Out:
# /usr/local/lib/python3.13/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.kdeplot(data=foreign_gifts_df, x="Log Foreign Gift Amount", hue="Gift Type")

plt.xlabel("Log Foreign Gift Amount")
plt.title("Density of Log Foreign Gift Amount by Gift Type")
plt.show()

# %% [markdown]
# 5. What are the top 15 countries in terms of the number of gifts? What are the top 15 countries in terms of the amount given?
# ---
# The top 15 countries in terms of the number of gifts are England, China, Canada, Japan, Switzerland, Saudi Arabia, France, Germany, Hong Kong, South Korea, Qatar, The Netherlands, Korea, India, and Taiwan. In terms of the amount given, the top 15 countries are Qatar, England, China, Saudi Arabia, Bermuda, Canada, Hong Kong, Japan, Switzerland, India, Germany, United Arab Emirates, France, Singapore, Australia
#
# Some countries appear under multiple names, like "Korea" and "South Korea." These totals may change if these labels are standardized.

# %%
country_counts = foreign_gifts_df.groupby("Country of Giftor").count()
country_counts["Foreign Gift Amount"].sort_values(ascending=False).head(15)
# Out:
# Country of Giftor
# ENGLAND            3655
# CHINA              2461
# CANADA             2344
# JAPAN              1896
# SWITZERLAND        1676
# SAUDI ARABIA       1610
# FRANCE             1437
# GERMANY            1394
# HONG KONG          1080
# SOUTH KOREA         811
# QATAR               693
# THE NETHERLANDS     512
# KOREA               452
# INDIA               434
# TAIWAN              381
# Name: Foreign Gift Amount, dtype: int64

# %%
country_amounts = foreign_gifts_df.groupby("Country of Giftor").sum(numeric_only=True)
country_amounts["Foreign Gift Amount"].sort_values(ascending=False).head(15)
# Out:
# Country of Giftor
# QATAR                   2706240869
# ENGLAND                 1464906771
# CHINA                   1237952112
# SAUDI ARABIA            1065205930
# BERMUDA                  899593972
# CANADA                   898160656
# HONG KONG                887402529
# JAPAN                    655954776
# SWITZERLAND              619899445
# INDIA                    539556490
# GERMANY                  442475605
# UNITED ARAB EMIRATES     431396357
# FRANCE                   405839396
# SINGAPORE                401157692
# AUSTRALIA                248409202
# Name: Foreign Gift Amount, dtype: int64

# %% [markdown]
# 6. Which giftors provide the most money, in total?
# ---
# Based on the raw data, Qatar Foundation provides the largest total amount of money. However, there are several giftor names that appear to refer to the same organization, such as “Qatar Foundation,” “Qatar Foundation/Qatar National Res,” and “Qatar Foundation for Education.” These are currently treated as separate giftors in the dataset.

# %%
giftor_amounts = foreign_gifts_df.groupby("Giftor Name").sum(numeric_only=True)
giftor_amounts["Foreign Gift Amount"].sort_values(ascending=False).head(15)
# Out:
# Giftor Name
# Qatar Foundation                       1166503744
# Qatar Foundation/Qatar National Res     796197000
# Qatar Foundation for Education          373945215
# Anonymous                               338793629
# Saudi Arabian Cultural Mission          275221475
# HCL                                     190000000
# Church of Jesus Christ of LDS           185203715
# Emirates Institute for Advanced Sc      170641244
# QIC                                     148355497
# Anonymous #9                             96334996
# Qatar National Research Fund             79021705
# Government of Saudi Arabia               75192434
# Contracting Party                        69996984
# CMKL University                          67700000
# Royal Embassy of Saudi Arabia            67062486
# Name: Foreign Gift Amount, dtype: int64

# %% [markdown]
# ## *Phase 2: AI-assisted Revision
# Keep Phase 1 frozen.

# %% [markdown]
# - **Phase 1 commit SHA ID:** b7dc7d5cc00a62ce37866d759ad98a59f9d6a724
# - **AI tool and model used:** ChatGPT 5.6 luna

# %% [markdown]
# ### *Prompts used

# %% [markdown]
# 1. Here is my Phase 1 notebook for this assignment. Can you review my answers and code and tell me what I should improve or fix for Phase 2? Check if my code actually answers each question and if my explanations of the graphs/results make sense. Also look for any data cleaning issues I might have missed, especially things like "Korea" vs "South Korea" or the different Qatar Foundation names. Please give me a short numbered list of the changes you recommend at the end.
# 2. I went through your list and either accepted, modified, or rejected your suggestions and provided my reasoning as to why. Please help me implement all the points according to my judgement.
# [Pasted the list and my reasoning on each point]

# %% [markdown]
# ### *AI-proposed changes

# %% [markdown]
# 1. Fix Q1.3 so cov(X,X) includes the full average/sum and clearly show why it equals \(s^2\).
# 2. Fix the Q1.4 counterexample by calculating means with addition instead of subtraction.
# 3. Revise the Foreign Gift Amount description to emphasize the long right tail and extreme outliers.
# 4. Calculate Gift Type proportions directly from the data instead of hard-coding the counts.
# 5. Filter to positive gift amounts before taking the log and explain why nonpositive values are excluded.
# 6. Revise the KDE interpretation to compare the locations and shapes of the gift-type distributions rather than treating density as the number of gifts.
# 7. Standardize country names such as KOREA and SOUTH KOREA, then recalculate both top-15 country rankings.
# 8. Standardize obvious duplicate giftor names, especially the Qatar Foundation variants, and recalculate the top giftors by total amount.

# %% [markdown]
# ### *Evaluation of AI suggestions

# %% [markdown]
# | Change | Decision | Reason and verification |
# |---|---|---|
# | 1 | `Accept` / modify / reject | This is an actual issue, I accidentally left out that summation so I will add that back |
# | 2 | `Accept` / modify / reject | Even though the counter example works, I calculated it wrong and just got lucky that it equaled the same thing, I will fix this |
# | 3 | Accept / `modify` / reject | I already recognize the right skew and maximum of 100 million dollars, so I will probably just fix the misleading wording. Instead of saying 'little to no' I can just say 'very rare' or 'very little' |
# | 4 | Accept / `modify` / reject | I believe I calculated these proportions correctly. I think it's asking me to directly calculate it from the dataframe instead of just reading it and hard calculating it myself, so this could be a code quality improvement |
# | 5 | `Accept` / modify / reject | Since the data actually has non positive gift amounts, my current approach could be problematic, so I'll take this suggestion and do it. |
# | 6 | `Accept` / modify / reject | This is a useful insight that I didn't think about, and I think comparing location, spread, and shape better answers the question. |
# | 7 | Accept / modify / `reject` | The dataset contains Korea and South Korea as separate labels. Even if they refer to the same country, I feel like this is too big of an assumption. |
# | 8 | Accept / `modify` / reject | This is the same problem as the 7th bullet but I feel like in this case Qatar Foundation variants are way more likely to be duplicates, so I would be okay combining them. |

# %% [markdown]
# ### *AI-assisted solution in full
# After the evaluation of AI suggestions, incorporate the accepted revisions into your Phase 1 solution and provide the final Phase 2 solution in full in the following cells.

# %% [markdown]
# ## Question 1
# ---
# 1. Show that $m(a + bX) = a+b \times m(X)$.
# Using the original formula:
# $$m(X) = \dfrac{1}{N} \sum_{i=1}^N x_i$$
# we can simplify
# $$m(a + bX) = \frac{1}{N}\sum_{i=1}^{N}(a + bx_i)$$
#
# $= \frac{1}{N}\left(\sum_{i=1}^{N}a + \sum_{i=1}^{N}bx_i\right)$
#
# $= \frac{1}{N}\left(Na + b\sum_{i=1}^{N}x_i\right)$
#
# $= a + b\left(\frac{1}{N}\sum_{i=1}^{N}x_i\right)$
#
# $= a + b \times m(X)$
#
# ---
# 2. Show that $\text{cov}(X,a+bY) = b \times \text{cov}(X,Y)$.
# Using the original formula:
# $$
# \text{cov}(X,Y) = \frac{1}{N} \sum_{i=1}^N (x_i - m(X))(y_i - m(Y)).
# $$
# We can simplify:
# $$\text{cov}(X,a+bY)=\frac{1}{N}\sum_{i=1}^{N}(x_i-m(X))((a+by_i)-(a+b\,m(Y)))$$
#
# $= \text{cov}(X,a+bY)=\frac{1}{N}\sum_{i=1}^{N}(x_i-m(X))((by_i-b\,m(Y)))$
#
# $= \text{cov}(X,a+bY)=\frac{1}{N}\sum_{i=1}^{N}(x_i-m(X))(b(y_i-m(Y)))$
#
# $= \text{cov}(X,a+bY)=b * \frac{1}{N}\sum_{i=1}^{N}(x_i-m(X))(y_i-m(Y))$
#
# $= \text{cov}(X,a+bY)=b * \text{cov}(X,Y)$
#
# ---
# 3. Show that $\text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X) $, and in particular that $\text{cov}(X,X) = s^2 $. Using the original formulas
# $$
# \text{cov}(X,Y) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(y_i - m(Y)).
# $$
# we can simplify:
# $$\text{cov}(a+bX,a+bX)$$
#
# $= \frac{1}{N}\sum_{i=1}^{N}((a+bx_i)-m(a+bX))((a+bx_i)-m(a+bX))$
#
# $= \frac{1}{N}\sum_{i=1}^{N}((a+bx_i) - (a + m(bX)))((a+bx_i) - (a + m(bX)))$
#
# $= \frac{1}{N}\sum_{i=1}^{N}(bx_i-m(bX))(bx_i-m(bX))$
#
# $= \frac{1}{N}\sum_{i=1}^{N}(bx_i-(b * m(X)))(bx_i-(b * m(X)))$
#
# $= \frac{1}{N}\sum_{i=1}^{N}(bx_i-(b * m(X))) ^ 2$
#
# $= \frac{1}{N}\sum_{i=1}^{N}(b * (x_i-m(X))) ^ 2$
#
# $= \frac{1}{N}\sum_{i=1}^{N}(b ^ 2 * (x_i-m(X))^ 2)$
#
# Since:
#
# $$\text{cov}(X, X) = \dfrac{1}{N} \sum_{i=1}^N (x_i-m(X))^ 2$$
#
# Then:
#
# $$b ^ 2 * \frac{1}{N}\sum_{i=1}^{N}(x_i-m(X)) ^ 2$$
# $= b ^ 2 * \text{cov}(X, X)$
#
# So:
#
# $$\text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X)$$
#
# then, using this formula:
# $$
# s^2 = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2.
# $$
# we can simplify the previous formula into:
#
# $$\frac{1}{N}\sum_{i=1}^{N}(b * (x_i-m(X))) ^ 2$$
#
# $$= b ^ 2 * \frac{1}{N}\sum_{i=1}^{N}(x_i-m(X)) ^ 2$$
#
# $$= b ^ 2 * s ^ 2$$
#
# so:
# $\text{cov}(X,X) = s^2 $
#
# ---
# 4. Consider a non-decreasing transformation $g()$. Is is always true that $m(g(X))= g(m(X))$?
#
# In order to prove this we can try finding a counterexample to prove that it is not ***always*** true.
#
# we can try this: g(x) = x^3 (this function is non-decreasing), and the numbers 0 and 2.
#
# m(g(x)):
#
# g(0) = 0, g(2) = 8. m(0, 8) = (8 + 0) / 2 = 4
#
# g(m(x)):
#
# m(0, 2) = (2 + 0) / 2 = 1, g(1) = 1
#
# Since 4 is not equal to 1, this statement is not ***always*** true.

# %% [markdown]
# ### Question 2:
#
# 1. Load the `./data/ForeignGifts_edu.csv` dataset.
# 2. For `Foreign Gift Amount`, create a histogram and describe the variable. Describe your findings.
# ---
# For `Foreign Gift Amount`, the histogram is heavily right skewed. The mean is around 588,000 dollars, while the median is only 94,615 dollars. most foreign gifts are on the lower end, while extremely large gifts are very rare. However, the max is 100 million dollars, meaning there are extreme outliers, creating a long right tail.

# %%
foreign_gifts_df2 = pd.read_csv(
    "A02-eda-and-visualization/data/ForeignGifts_edu.csv"
)

foreign_gifts_df2["Foreign Gift Amount"].hist(bins=20, grid=False)

plt.xlabel("Foreign Gift Amount")
plt.ylabel("Count")
plt.title("Foreign Gift Amount")
plt.show()

foreign_gifts_df2["Foreign Gift Amount"].describe()
# Out:
# count    2.822100e+04
# mean     5.882327e+05
# std      3.222011e+06
# min     -5.377700e+05
# 25%      5.700000e+03
# 50%      9.461500e+04
# 75%      3.761420e+05
# max      1.000000e+08
# Name: Foreign Gift Amount, dtype: float64

# %% [markdown]
# 3. For `Gift Type`, create a histogram or value counts table. What proportion of the gifts are contracts, real estate, and monetary gifts?
# ---
# There's 17274 contracts, 10936 monetary gifts, and 11 real estate gifts. The percentage of gifts that were contracts is around 61.2%, for Monetary Gifts it was 38.8%, and for Real estate it was 0.04%.

# %%
foreign_gifts_df2["Gift Type"].value_counts(normalize=True) * 100
# Out:
# Gift Type
# Contract         61.209737
# Monetary Gift    38.751285
# Real Estate       0.038978
# Name: proportion, dtype: float64

# %% [markdown]
# 4. Create a kernel density plot of the log of `Foreign Gift Amount`, and then a kernel density plot of the log of `Foreign Gift Amount` conditional on gift type. Do you notice any patterns?
# ---
# For the log/KDE analysis, I filtered the data to only include positive foreign gift amounts because np.log is not defined for values less than or equal to zero.
#
# Contracts tend to be more concentrated around higher gift amounts, while monetary gifts are more spread out. Monetary gifts also seem to have two peaks, one around 5 and another around 13, showing groups of both smaller and larger gifts. The two gift types overlap a lot at the higher amounts. There are very few real estate gifts, so it is difficult to make conclusions about their distribution.

# %%
positive_gifts_df = foreign_gifts_df2[
    foreign_gifts_df2["Foreign Gift Amount"] > 0
].copy()

positive_gifts_df["Log Foreign Gift Amount"] = np.log(
    positive_gifts_df["Foreign Gift Amount"]
)
sns.kdeplot(
    data=positive_gifts_df,
    x="Log Foreign Gift Amount"
)

plt.xlabel("Log Foreign Gift Amount")
plt.show()

# %%
sns.kdeplot(
    data=positive_gifts_df,
    x="Log Foreign Gift Amount",
    hue="Gift Type"
)

plt.xlabel("Log Foreign Gift Amount")
plt.show()

# %% [markdown]
# 5. What are the top 15 countries in terms of the number of gifts? What are the top 15 countries in terms of the amount given?
# ---
# The top 15 countries in terms of the number of gifts are England, China, Canada, Japan, Switzerland, Saudi Arabia, France, Germany, Hong Kong, South Korea, Qatar, The Netherlands, Korea, India, and Taiwan. In terms of the amount given, the top 15 countries are Qatar, England, China, Saudi Arabia, Bermuda, Canada, Hong Kong, Japan, Switzerland, India, Germany, United Arab Emirates, France, Singapore, Australia
#
# Some countries appear under multiple names, like "Korea" and "South Korea." These totals may change if these labels are standardized.

# %%
country_counts = foreign_gifts_df2.groupby("Country of Giftor").count()
country_counts["Foreign Gift Amount"].sort_values(ascending=False).head(15)
# Out:
# Country of Giftor
# ENGLAND            3655
# CHINA              2461
# CANADA             2344
# JAPAN              1896
# SWITZERLAND        1676
# SAUDI ARABIA       1610
# FRANCE             1437
# GERMANY            1394
# HONG KONG          1080
# SOUTH KOREA         811
# QATAR               693
# THE NETHERLANDS     512
# KOREA               452
# INDIA               434
# TAIWAN              381
# Name: Foreign Gift Amount, dtype: int64

# %%
country_amounts = foreign_gifts_df2.groupby("Country of Giftor").sum(numeric_only=True)
country_amounts["Foreign Gift Amount"].sort_values(ascending=False).head(15)
# Out:
# Country of Giftor
# QATAR                   2706240869
# ENGLAND                 1464906771
# CHINA                   1237952112
# SAUDI ARABIA            1065205930
# BERMUDA                  899593972
# CANADA                   898160656
# HONG KONG                887402529
# JAPAN                    655954776
# SWITZERLAND              619899445
# INDIA                    539556490
# GERMANY                  442475605
# UNITED ARAB EMIRATES     431396357
# FRANCE                   405839396
# SINGAPORE                401157692
# AUSTRALIA                248409202
# Name: Foreign Gift Amount, dtype: int64

# %% [markdown]
# 6. Which giftors provide the most money, in total?
# ---
# After cleaning, the Qatar Foundation still seems to be the number one giftor in terms of providing the most amount of money.

# %%
foreign_gifts_df2["Giftor Name Clean"] = foreign_gifts_df2["Giftor Name"]

foreign_gifts_df2["Giftor Name Clean"] = (
    foreign_gifts_df2["Giftor Name Clean"]
    .replace({
        "Qatar Foundation for Education": "Qatar Foundation",
        "Qatar Foundation/Qatar National Res": "Qatar Foundation"
    })
)
top_giftors = (
    foreign_gifts_df2
    .groupby("Giftor Name Clean")["Foreign Gift Amount"]
    .sum()
    .sort_values(ascending=False)
    .head(15)
)

top_giftors
# Out:
# Giftor Name Clean
# Qatar Foundation                      2336645959
# Anonymous                              338793629
# Saudi Arabian Cultural Mission         275221475
# HCL                                    190000000
# Church of Jesus Christ of LDS          185203715
# Emirates Institute for Advanced Sc     170641244
# QIC                                    148355497
# Anonymous #9                            96334996
# Qatar National Research Fund            79021705
# Government of Saudi Arabia              75192434
# Contracting Party                       69996984
# CMKL University                         67700000
# Royal Embassy of Saudi Arabia           67062486
# Sanofi-Aventis Recerche                 62106706
# Saudi Arabia                            59450098
# Name: Foreign Gift Amount, dtype: int64

# %% [markdown]
# ### *Reflection on AI assistance
# In your own words without generative AI.

# %% [markdown]
# The main improvements were correcting a few small errors in my original work and improving how I analyzed the KDE plot. The AI suggested comparing the location, spread, and shape of the distributions, which was a useful approach that I didn't think of initially. However, there were also some limitations in its suggestions. One was when it assumed that “Korea” and “South Korea” should be combined during data cleaning. I decided not to make this change because the dataset treats them as separate categories, and I did not have enough information to assume they referred to the same thing. It also misunderstood some of my calculations, and suggested that I had manually calculated proportions when the counts originally came from value_counts(). Though I did hard calculate it, it still came from the value_counts() function so I ended up modifying that suggestion.
#
# I verified my final solution by reading over the revised code to make sure it still answered each question using the appropriate data and methods. I also reran the code to make sure it executed correctly and produced reasonable results. For the KDE plot specifically, I checked that my revised interpretation matched the resulting graph after filtering nonpositive values.
#
# My main remaining concern is ambiguous category cleaning, specifically “Korea” versus “South Korea.” I am a bit concerned that removing nonpositive gift amounts for the log transformation was not the right call, and that it could remove observations that may have been there for a reason. There were also very few Real Estate gifts; even though this came directly from the dataset, I still question how meaningful they are.
